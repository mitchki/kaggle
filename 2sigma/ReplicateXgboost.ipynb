# %%
import os
import sys
import operator
import numpy as np
import pandas as pd
from scipy import sparse
import xgboost as xgb
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# Out:
# /home/kmitchell/anaconda2/envs/py35/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data_path = "~/data/TwoSigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)


#pd.read_json("~/data/TwoSigma/train.json")
#pd.read_json("/home/kmitchell/data/TwoSigma/train.json")
# Out:
# (49352, 15)
# (74659, 14)

# %%
train_df.head()
# Out:
#         bathrooms  bedrooms                       building_id  \
# 10            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 10000         1.0         2  c5c8a357cba207596b04d1afd1e4f130
# 100004        1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 100007        1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 100013        1.0         4                                 0
#
#                     created  \
# 10      2016-06-24 07:54:24
# 10000   2016-06-12 12:19:27
# 100004  2016-04-17 03:26:41
# 100007  2016-04-18 02:22:02
# 100013  2016-04-28 01:32:41
#
#                                               description  \
# 10      A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 10000
# 100004  Top Top West Village location, beautiful Pre-w...
# 100007  Building Amenities - Garage - Garden - fitness...
# 100013  Beautifully renovated 3 bedroom flex 4 bedroom...
#
#             display_address  \
# 10      Metropolitan Avenue
# 10000       Columbus Avenue
# 100004          W 13 Street
# 100007     East 49th Street
# 100013    West 143rd Street
#
#                                                  features interest_level  \
# 10                                                     []         medium
# 10000   [Doorman, Elevator, Fitness Center, Cats Allow...            low
# 100004  [Laundry In Building, Dishwasher, Hardwood Flo...           high
# 100007                          [Hardwood Floors, No Fee]            low
# 100013                                          [Pre-War]            low
#
#         latitude  listing_id  longitude                        manager_id  \
# 10       40.7145     7211212   -73.9425  5ba989232d0489da1b5f2c45f6688adc
# 10000    40.7947     7150865   -73.9667  7533621a882f71e25173b27e3139d83d
# 100004   40.7388     6887163   -74.0018  d9039c43983f6e564b1482b273bd7b01
# 100007   40.7539     6888711   -73.9677  1067e078446a7897d2da493d2f741316
# 100013   40.8241     6934781   -73.9493  98e13ad4b495b9613cef886d79a6291f
#
#                                                    photos  price  \
# 10      [https://photos.renthop.com/2/7211212_1ed4542e...   3000
# 10000   [https://photos.renthop.com/2/7150865_be3306c5...   5465
# 100004  [https://photos.renthop.com/2/6887163_de85c427...   2850
# 100007  [https://photos.renthop.com/2/6888711_6e660cee...   3275
# 100013  [https://photos.renthop.com/2/6934781_1fa4b41a...   3350
#
#                  street_address
# 10      792 Metropolitan Avenue
# 10000       808 Columbus Avenue
# 100004          241 W 13 Street
# 100007     333 East 49th Street
# 100013    500 West 143rd Street

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=42, num_rounds=1000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
train_df.features[:5]
# Out:
# 10                                                       []
# 10000     [Doorman, Elevator, Fitness Center, Cats Allow...
# 100004    [Laundry In Building, Dishwasher, Hardwood Flo...
# 100007                            [Hardwood Floors, No Fee]
# 100013                                            [Pre-War]
# Name: features, dtype: object

# %%
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour
train_df["created_dayofweek"] = train_df["created"].dt.weekday
test_df["created_dayofweek"] = test_df["created"].dt.weekday



# adding all these new features to use list #
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year", "created_month", "created_day", "listing_id", "created_hour", "created_dayofweek"])

# %%
features_to_use
# Out:
# ['bathrooms',
#  'bedrooms',
#  'latitude',
#  'longitude',
#  'price',
#  'num_photos',
#  'num_features',
#  'num_description_words',
#  'created_year',
#  'created_month',
#  'created_day',
#  'listing_id',
#  'created_hour',
#  'created_dayofweek']

# %%
categorical = ["display_address", "manager_id", "building_id", "street_address"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
train_df.manager_id[:10]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49352 entries, 10 to 99994
# Data columns (total 23 columns):
# bathrooms                49352 non-null float64
# bedrooms                 49352 non-null int64
# building_id              49352 non-null int64
# created                  49352 non-null datetime64[ns]
# description              49352 non-null object
# display_address          49352 non-null int64
# features                 49352 non-null object
# interest_level           49352 non-null object
# latitude                 49352 non-null float64
# listing_id               49352 non-null int64
# longitude                49352 non-null float64
# manager_id               49352 non-null int64
# photos                   49352 non-null object
# price                    49352 non-null int64
# street_address           49352 non-null int64
# num_photos               49352 non-null int64
# num_features             49352 non-null int64
# num_description_words    49352 non-null int64
# created_year             49352 non-null int64
# created_month            49352 non-null int64
# created_day              49352 non-null int64
# created_hour             49352 non-null int64
# created_dayofweek        49352 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(15), object(4)
# memory usage: 9.0+ MB

# %%
train_df['features'] = train_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
test_df['features'] = test_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
train_df['features'] = train_df['features'].str.lower()
test_df['features'] = test_df['features'].str.lower()
print(train_df["features"].head())
# Out:
# 10
# 10000     doorman elevator fitness_center cats_allowed d...
# 100004    laundry_in_building dishwasher hardwood_floors...
# 100007                               hardwood_floors no_fee
# 100013                                              pre-war
# Name: features, dtype: object

# %%
tfidf = CountVectorizer(stop_words='english', max_features=100)
tr_sparse = tfidf.fit_transform(train_df["features"])
te_sparse = tfidf.transform(test_df["features"])

# %%
train_df['description'] = train_df['description'].str.lower()
test_df['description'] = test_df['description'].str.lower()
print(train_df["description"].head())
tfidf = CountVectorizer(stop_words='english', max_features=100)
tra_sparse = tfidf.fit_transform(train_df["features"])
tes_sparse = tfidf.transform(test_df["features"])
# Out:
# 10        a brand new 3 bedroom 1.5 bath apartmentenjoy ...
# 10000
# 100004    top top west village location, beautiful pre-w...
# 100007    building amenities - garage - garden - fitness...
# 100013    beautifully renovated 3 bedroom flex 4 bedroom...
# Name: description, dtype: object

# %%
#train_df.to_pickle('train_df.pkl')
#test_df.to_pickle('test_df.pkl')

# %% [markdown]
# ### Train and test data frames created above and saved to pkl file
# pkl file loaded below and used for model building and evaluation

# %%
train_X = sparse.hstack([train_df[features_to_use], tr_sparse,tra_sparse]).tocsr()
test_X = sparse.hstack([test_df[features_to_use], te_sparse, tes_sparse]).tocsr()

target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))
print(train_X.shape, test_X.shape)
# Out:
# (49352, 218) (74659, 218)

# %%
cv_scores = []
kf = model_selection.KFold(n_splits=7, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(train_X.shape[0])):
        dev_X, val_X = train_X[dev_index,:], train_X[val_index,:]
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# [0]	train-mlogloss:1.03943	test-mlogloss:1.03953
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:0.98739	test-mlogloss:0.98804
# [2]	train-mlogloss:0.945497	test-mlogloss:0.946728
# [3]	train-mlogloss:0.906603	test-mlogloss:0.908219
# [4]	train-mlogloss:0.872682	test-mlogloss:0.875148
# [5]	train-mlogloss:0.845483	test-mlogloss:0.848496
# [6]	train-mlogloss:0.819229	test-mlogloss:0.822669
# [7]	train-mlogloss:0.796226	test-mlogloss:0.800114
# [8]	train-mlogloss:0.775539	test-mlogloss:0.780028
# [9]	train-mlogloss:0.758479	test-mlogloss:0.76342
# [10]	train-mlogloss:0.74271	test-mlogloss:0.748037
# [11]	train-mlogloss:0.728749	test-mlogloss:0.734623
# [12]	train-mlogloss:0.716505	test-mlogloss:0.722813
# [13]	train-mlogloss:0.70577	test-mlogloss:0.712372
# [14]	train-mlogloss:0.694535	test-mlogloss:0.701855
# [15]	train-mlogloss:0.6843	test-mlogloss:0.692392
# [16]	train-mlogloss:0.675384	test-mlogloss:0.684093
# [17]	train-mlogloss:0.667031	test-mlogloss:0.676324
# [18]	train-mlogloss:0.659543	test-mlogloss:0.669432
# [19]	train-mlogloss:0.653679	test-mlogloss:0.663871
# [20]	train-mlogloss:0.647865	test-mlogloss:0.658521
# [21]	train-mlogloss:0.642396	test-mlogloss:0.653561
# [22]	train-mlogloss:0.637086	test-mlogloss:0.648693
# [23]	train-mlogloss:0.63183	test-mlogloss:0.643865
# [24]	train-mlogloss:0.626687	test-mlogloss:0.639406
# [25]	train-mlogloss:0.62245	test-mlogloss:0.635874
# [26]	train-mlogloss:0.617655	test-mlogloss:0.631877
# [27]	train-mlogloss:0.613685	test-mlogloss:0.628585
# [28]	train-mlogloss:0.610368	test-mlogloss:0.625849
# [29]	train-mlogloss:0.607242	test-mlogloss:0.623248
# [30]	train-mlogloss:0.603861	test-mlogloss:0.620358
# [31]	train-mlogloss:0.600727	test-mlogloss:0.617745
# [32]	train-mlogloss:0.597009	test-mlogloss:0.614755
# [33]	train-mlogloss:0.594936	test-mlogloss:0.613157
# [34]	train-mlogloss:0.592235	test-mlogloss:0.611018
# [35]	train-mlogloss:0.589871	test-mlogloss:0.609043
# [36]	train-mlogloss:0.58713	test-mlogloss:0.607123
# [37]	train-mlogloss:0.584384	test-mlogloss:0.605209
# [38]	train-mlogloss:0.581585	test-mlogloss:0.603157
# [39]	train-mlogloss:0.578929	test-mlogloss:0.601315
# [40]	train-mlogloss:0.576883	test-mlogloss:0.5997
# [41]	train-mlogloss:0.575265	test-mlogloss:0.598514
# [42]	train-mlogloss:0.572462	test-mlogloss:0.596395
# [43]	train-mlogloss:0.570361	test-mlogloss:0.594842
# [44]	train-mlogloss:0.568796	test-mlogloss:0.593898
# [45]	train-mlogloss:0.566651	test-mlogloss:0.592273
# [46]	train-mlogloss:0.564711	test-mlogloss:0.591079
# [47]	train-mlogloss:0.563083	test-mlogloss:0.590208
# [48]	train-mlogloss:0.561566	test-mlogloss:0.589224
# [49]	train-mlogloss:0.559447	test-mlogloss:0.58787
# [50]	train-mlogloss:0.557507	test-mlogloss:0.586731
# [51]	train-mlogloss:0.555425	test-mlogloss:0.585412
# [52]	train-mlogloss:0.553944	test-mlogloss:0.584647
# [53]	train-mlogloss:0.552023	test-mlogloss:0.583389
# [54]	train-mlogloss:0.550211	test-mlogloss:0.582442
# [55]	train-mlogloss:0.5492	test-mlogloss:0.581908
# [56]	train-mlogloss:0.547512	test-mlogloss:0.581365
# [57]	train-mlogloss:0.546217	test-mlogloss:0.580662
# [58]	train-mlogloss:0.544901	test-mlogloss:0.58007
# [59]	train-mlogloss:0.54365	test-mlogloss:0.579545
# [60]	train-mlogloss:0.542374	test-mlogloss:0.57894
# [61]	train-mlogloss:0.540861	test-mlogloss:0.578169
# [62]	train-mlogloss:0.539553	test-mlogloss:0.577528
# [63]	train-mlogloss:0.538171	test-mlogloss:0.576899
# [64]	train-mlogloss:0.536441	test-mlogloss:0.575725
# [65]	train-mlogloss:0.535057	test-mlogloss:0.575066
# [66]	train-mlogloss:0.533855	test-mlogloss:0.57464
# [67]	train-mlogloss:0.53286	test-mlogloss:0.574327
# [68]	train-mlogloss:0.53168	test-mlogloss:0.573851
# [69]	train-mlogloss:0.530276	test-mlogloss:0.573259
# [70]	train-mlogloss:0.528909	test-mlogloss:0.572758
# [71]	train-mlogloss:0.527503	test-mlogloss:0.572038
# [72]	train-mlogloss:0.526349	test-mlogloss:0.571449
# [73]	train-mlogloss:0.525076	test-mlogloss:0.570997
# [74]	train-mlogloss:0.523994	test-mlogloss:0.570494
# [75]	train-mlogloss:0.522496	test-mlogloss:0.569652
# [76]	train-mlogloss:0.521256	test-mlogloss:0.569124
# [77]	train-mlogloss:0.520271	test-mlogloss:0.56867
# [78]	train-mlogloss:0.519047	test-mlogloss:0.568043
# [79]	train-mlogloss:0.517928	test-mlogloss:0.567644
# [80]	train-mlogloss:0.517169	test-mlogloss:0.567447
# [81]	train-mlogloss:0.516334	test-mlogloss:0.567066
# [82]	train-mlogloss:0.515306	test-mlogloss:0.566648
# [83]	train-mlogloss:0.514296	test-mlogloss:0.566212
# [84]	train-mlogloss:0.513412	test-mlogloss:0.565937
# [85]	train-mlogloss:0.512457	test-mlogloss:0.565586
# [86]	train-mlogloss:0.511346	test-mlogloss:0.565102
# [87]	train-mlogloss:0.510334	test-mlogloss:0.56459
# [88]	train-mlogloss:0.50938	test-mlogloss:0.56418
# [89]	train-mlogloss:0.508346	test-mlogloss:0.563886
# [90]	train-mlogloss:0.507492	test-mlogloss:0.56353
# [91]	train-mlogloss:0.506342	test-mlogloss:0.563071
# [92]	train-mlogloss:0.505678	test-mlogloss:0.562855
# [93]	train-mlogloss:0.504846	test-mlogloss:0.562573
# [94]	train-mlogloss:0.503704	test-mlogloss:0.562191
# [95]	train-mlogloss:0.502746	test-mlogloss:0.561958
# [96]	train-mlogloss:0.501531	test-mlogloss:0.561765
# [97]	train-mlogloss:0.500405	test-mlogloss:0.561385
# [98]	train-mlogloss:0.499715	test-mlogloss:0.561178
# [99]	train-mlogloss:0.498826	test-mlogloss:0.561061
# [100]	train-mlogloss:0.497508	test-mlogloss:0.560468
# [101]	train-mlogloss:0.496549	test-mlogloss:0.560219
# [102]	train-mlogloss:0.495576	test-mlogloss:0.559851
# [103]	train-mlogloss:0.494767	test-mlogloss:0.559533
# [104]	train-mlogloss:0.493845	test-mlogloss:0.559245
# [105]	train-mlogloss:0.492854	test-mlogloss:0.559151
# [106]	train-mlogloss:0.492297	test-mlogloss:0.558964
# [107]	train-mlogloss:0.491382	test-mlogloss:0.558841
# [108]	train-mlogloss:0.490726	test-mlogloss:0.558633
# [109]	train-mlogloss:0.489887	test-mlogloss:0.558262
# [110]	train-mlogloss:0.489121	test-mlogloss:0.557943
# [111]	train-mlogloss:0.488181	test-mlogloss:0.557565
# [112]	train-mlogloss:0.487154	test-mlogloss:0.557392
# [113]	train-mlogloss:0.486316	test-mlogloss:0.557276
# [114]	train-mlogloss:0.485469	test-mlogloss:0.556997
# [115]	train-mlogloss:0.484581	test-mlogloss:0.556675
# [116]	train-mlogloss:0.483938	test-mlogloss:0.556425
# [117]	train-mlogloss:0.482935	test-mlogloss:0.556222
# [118]	train-mlogloss:0.482145	test-mlogloss:0.556055
# [119]	train-mlogloss:0.48137	test-mlogloss:0.555872
# [120]	train-mlogloss:0.48068	test-mlogloss:0.555731
# [121]	train-mlogloss:0.479796	test-mlogloss:0.555425
# [122]	train-mlogloss:0.479233	test-mlogloss:0.555437
# [123]	train-mlogloss:0.47864	test-mlogloss:0.555173
# [124]	train-mlogloss:0.477869	test-mlogloss:0.554911
# [125]	train-mlogloss:0.477036	test-mlogloss:0.554717
# [126]	train-mlogloss:0.476435	test-mlogloss:0.554521
# [127]	train-mlogloss:0.475708	test-mlogloss:0.554296
# [128]	train-mlogloss:0.474683	test-mlogloss:0.554036
# [129]	train-mlogloss:0.473848	test-mlogloss:0.553894
# [130]	train-mlogloss:0.473143	test-mlogloss:0.553799
# [131]	train-mlogloss:0.472338	test-mlogloss:0.55354
# [132]	train-mlogloss:0.471569	test-mlogloss:0.553337
# [133]	train-mlogloss:0.470765	test-mlogloss:0.553062
# [134]	train-mlogloss:0.470081	test-mlogloss:0.552847
# [135]	train-mlogloss:0.469359	test-mlogloss:0.552685
# [136]	train-mlogloss:0.468642	test-mlogloss:0.552319
# [137]	train-mlogloss:0.468076	test-mlogloss:0.552261
# [138]	train-mlogloss:0.467339	test-mlogloss:0.552082
# [139]	train-mlogloss:0.466621	test-mlogloss:0.551975
# [140]	train-mlogloss:0.466087	test-mlogloss:0.551869
# [141]	train-mlogloss:0.465203	test-mlogloss:0.551651
# [142]	train-mlogloss:0.464395	test-mlogloss:0.551453
# [143]	train-mlogloss:0.463591	test-mlogloss:0.551281
# [144]	train-mlogloss:0.463	test-mlogloss:0.551091
# [145]	train-mlogloss:0.462383	test-mlogloss:0.550885
# [146]	train-mlogloss:0.461676	test-mlogloss:0.55062
# [147]	train-mlogloss:0.460828	test-mlogloss:0.550611
# [148]	train-mlogloss:0.460073	test-mlogloss:0.550336
# [149]	train-mlogloss:0.459477	test-mlogloss:0.550224
# [150]	train-mlogloss:0.458677	test-mlogloss:0.549882
# [151]	train-mlogloss:0.458047	test-mlogloss:0.549857
# [152]	train-mlogloss:0.457483	test-mlogloss:0.549694
# [153]	train-mlogloss:0.456868	test-mlogloss:0.549478
# [154]	train-mlogloss:0.456345	test-mlogloss:0.549341
# [155]	train-mlogloss:0.455683	test-mlogloss:0.549239
# [156]	train-mlogloss:0.454883	test-mlogloss:0.54914
# [157]	train-mlogloss:0.454336	test-mlogloss:0.549054
# [158]	train-mlogloss:0.45389	test-mlogloss:0.548984
# [159]	train-mlogloss:0.453277	test-mlogloss:0.548868
# [160]	train-mlogloss:0.452746	test-mlogloss:0.548762
# [161]	train-mlogloss:0.452051	test-mlogloss:0.548739
# [162]	train-mlogloss:0.451642	test-mlogloss:0.548663
# [163]	train-mlogloss:0.451201	test-mlogloss:0.548479
# [164]	train-mlogloss:0.450499	test-mlogloss:0.548334
# [165]	train-mlogloss:0.449989	test-mlogloss:0.548253
# [166]	train-mlogloss:0.449238	test-mlogloss:0.548057
# [167]	train-mlogloss:0.448751	test-mlogloss:0.547903
# [168]	train-mlogloss:0.448089	test-mlogloss:0.54789
# [169]	train-mlogloss:0.447525	test-mlogloss:0.547748
# [170]	train-mlogloss:0.446756	test-mlogloss:0.547676
# [171]	train-mlogloss:0.446153	test-mlogloss:0.547467
# [172]	train-mlogloss:0.445406	test-mlogloss:0.547451
# [173]	train-mlogloss:0.444781	test-mlogloss:0.547211
# [174]	train-mlogloss:0.444199	test-mlogloss:0.547218
# [175]	train-mlogloss:0.443518	test-mlogloss:0.547077
# [176]	train-mlogloss:0.443041	test-mlogloss:0.547009
# [177]	train-mlogloss:0.442431	test-mlogloss:0.546833
# [178]	train-mlogloss:0.441914	test-mlogloss:0.546781
# [179]	train-mlogloss:0.441422	test-mlogloss:0.546523
# [180]	train-mlogloss:0.44066	test-mlogloss:0.546213
# [181]	train-mlogloss:0.439975	test-mlogloss:0.546205
# [182]	train-mlogloss:0.439241	test-mlogloss:0.546243
# [183]	train-mlogloss:0.438547	test-mlogloss:0.545945
# [184]	train-mlogloss:0.437909	test-mlogloss:0.545884
# [185]	train-mlogloss:0.437293	test-mlogloss:0.54586
# [186]	train-mlogloss:0.436632	test-mlogloss:0.545602
# [187]	train-mlogloss:0.435889	test-mlogloss:0.545423
# [188]	train-mlogloss:0.43531	test-mlogloss:0.545346
# [189]	train-mlogloss:0.43456	test-mlogloss:0.545263
# [190]	train-mlogloss:0.434161	test-mlogloss:0.54517
# [191]	train-mlogloss:0.433615	test-mlogloss:0.545116
# [192]	train-mlogloss:0.43298	test-mlogloss:0.544968
# [193]	train-mlogloss:0.432391	test-mlogloss:0.544928
# [194]	train-mlogloss:0.431931	test-mlogloss:0.545016
# [195]	train-mlogloss:0.431376	test-mlogloss:0.544859
# [196]	train-mlogloss:0.431009	test-mlogloss:0.544852
# [197]	train-mlogloss:0.430332	test-mlogloss:0.544891
# [198]	train-mlogloss:0.42992	test-mlogloss:0.544803
# [199]	train-mlogloss:0.429407	test-mlogloss:0.544891
# [200]	train-mlogloss:0.428862	test-mlogloss:0.544791
# [201]	train-mlogloss:0.428044	test-mlogloss:0.544645
# [202]	train-mlogloss:0.427551	test-mlogloss:0.544474
# [203]	train-mlogloss:0.426877	test-mlogloss:0.544415
# [204]	train-mlogloss:0.426147	test-mlogloss:0.54411
# [205]	train-mlogloss:0.425656	test-mlogloss:0.543937
# [206]	train-mlogloss:0.425013	test-mlogloss:0.543803
# [207]	train-mlogloss:0.424391	test-mlogloss:0.543757
# [208]	train-mlogloss:0.423872	test-mlogloss:0.543719
# [209]	train-mlogloss:0.423249	test-mlogloss:0.543689
# [210]	train-mlogloss:0.422524	test-mlogloss:0.543541
# [211]	train-mlogloss:0.421989	test-mlogloss:0.543514
# [212]	train-mlogloss:0.421554	test-mlogloss:0.543376
# [213]	train-mlogloss:0.421032	test-mlogloss:0.543163
# [214]	train-mlogloss:0.420225	test-mlogloss:0.543161
# [215]	train-mlogloss:0.419883	test-mlogloss:0.543078
# [216]	train-mlogloss:0.419342	test-mlogloss:0.542918
# [217]	train-mlogloss:0.418891	test-mlogloss:0.542934
# [218]	train-mlogloss:0.418406	test-mlogloss:0.542953
# [219]	train-mlogloss:0.417963	test-mlogloss:0.542927
# [220]	train-mlogloss:0.417313	test-mlogloss:0.542806
# [221]	train-mlogloss:0.416626	test-mlogloss:0.542675
# [222]	train-mlogloss:0.416112	test-mlogloss:0.542479
# [223]	train-mlogloss:0.415611	test-mlogloss:0.542561
# [224]	train-mlogloss:0.415063	test-mlogloss:0.54248
# [225]	train-mlogloss:0.414421	test-mlogloss:0.542411
# [226]	train-mlogloss:0.413924	test-mlogloss:0.542352
# [227]	train-mlogloss:0.413398	test-mlogloss:0.542331
# [228]	train-mlogloss:0.412864	test-mlogloss:0.54219
# [229]	train-mlogloss:0.412299	test-mlogloss:0.542119
# [230]	train-mlogloss:0.411791	test-mlogloss:0.542069
# [231]	train-mlogloss:0.411362	test-mlogloss:0.542065
# [232]	train-mlogloss:0.410984	test-mlogloss:0.541958
# [233]	train-mlogloss:0.41062	test-mlogloss:0.541876
# [234]	train-mlogloss:0.410116	test-mlogloss:0.541851
# [235]	train-mlogloss:0.409628	test-mlogloss:0.54187
# [236]	train-mlogloss:0.409408	test-mlogloss:0.541848
# [237]	train-mlogloss:0.408933	test-mlogloss:0.541851
# [238]	train-mlogloss:0.408267	test-mlogloss:0.541832
# [239]	train-mlogloss:0.407774	test-mlogloss:0.541802
# [240]	train-mlogloss:0.407223	test-mlogloss:0.541715
# [241]	train-mlogloss:0.406575	test-mlogloss:0.541604
# [242]	train-mlogloss:0.405976	test-mlogloss:0.541455
# [243]	train-mlogloss:0.405606	test-mlogloss:0.541423
# [244]	train-mlogloss:0.405283	test-mlogloss:0.541288
# [245]	train-mlogloss:0.404704	test-mlogloss:0.541305
# [246]	train-mlogloss:0.404295	test-mlogloss:0.541334
# [247]	train-mlogloss:0.403875	test-mlogloss:0.541241
# [248]	train-mlogloss:0.403295	test-mlogloss:0.541068
# [249]	train-mlogloss:0.402907	test-mlogloss:0.54108
# [250]	train-mlogloss:0.402507	test-mlogloss:0.540916
# [251]	train-mlogloss:0.402128	test-mlogloss:0.540874
# [252]	train-mlogloss:0.401606	test-mlogloss:0.540892
# [253]	train-mlogloss:0.401082	test-mlogloss:0.540803
# [254]	train-mlogloss:0.400538	test-mlogloss:0.540843
# [255]	train-mlogloss:0.400118	test-mlogloss:0.540805
# [256]	train-mlogloss:0.399344	test-mlogloss:0.540604
# [257]	train-mlogloss:0.398991	test-mlogloss:0.540545
# [258]	train-mlogloss:0.398261	test-mlogloss:0.540394
# [259]	train-mlogloss:0.397785	test-mlogloss:0.540206
# [260]	train-mlogloss:0.397257	test-mlogloss:0.540215
# [261]	train-mlogloss:0.396679	test-mlogloss:0.540257
# [262]	train-mlogloss:0.396201	test-mlogloss:0.540311
# [263]	train-mlogloss:0.395581	test-mlogloss:0.540248
# [264]	train-mlogloss:0.394988	test-mlogloss:0.540067
# [265]	train-mlogloss:0.394506	test-mlogloss:0.540107
# [266]	train-mlogloss:0.394225	test-mlogloss:0.5401
# [267]	train-mlogloss:0.393884	test-mlogloss:0.540057
# [268]	train-mlogloss:0.393413	test-mlogloss:0.54002
# [269]	train-mlogloss:0.392939	test-mlogloss:0.53994
# [270]	train-mlogloss:0.392433	test-mlogloss:0.539966
# [271]	train-mlogloss:0.391991	test-mlogloss:0.539949
# [272]	train-mlogloss:0.391607	test-mlogloss:0.539903
# [273]	train-mlogloss:0.391239	test-mlogloss:0.539841
# [274]	train-mlogloss:0.390976	test-mlogloss:0.539832
# [275]	train-mlogloss:0.390437	test-mlogloss:0.539755
# [276]	train-mlogloss:0.389997	test-mlogloss:0.539782
# [277]	train-mlogloss:0.389373	test-mlogloss:0.539659
# [278]	train-mlogloss:0.388909	test-mlogloss:0.539663
# [279]	train-mlogloss:0.388524	test-mlogloss:0.539585
# [280]	train-mlogloss:0.388112	test-mlogloss:0.539451
# [281]	train-mlogloss:0.387605	test-mlogloss:0.539539
# [282]	train-mlogloss:0.387165	test-mlogloss:0.53956
# [283]	train-mlogloss:0.386705	test-mlogloss:0.539513
# [284]	train-mlogloss:0.386121	test-mlogloss:0.539412
# [285]	train-mlogloss:0.385644	test-mlogloss:0.539387
# [286]	train-mlogloss:0.385211	test-mlogloss:0.539421
# [287]	train-mlogloss:0.384893	test-mlogloss:0.539411
# [288]	train-mlogloss:0.384516	test-mlogloss:0.539342
# [289]	train-mlogloss:0.38414	test-mlogloss:0.539249
# [290]	train-mlogloss:0.383603	test-mlogloss:0.539194
# [291]	train-mlogloss:0.383236	test-mlogloss:0.539127
# [292]	train-mlogloss:0.382806	test-mlogloss:0.539152
# [293]	train-mlogloss:0.382355	test-mlogloss:0.539217
# [294]	train-mlogloss:0.38194	test-mlogloss:0.539223
# [295]	train-mlogloss:0.381339	test-mlogloss:0.538987
# [296]	train-mlogloss:0.380725	test-mlogloss:0.538894
# [297]	train-mlogloss:0.380271	test-mlogloss:0.538916
# [298]	train-mlogloss:0.379874	test-mlogloss:0.538849
# [299]	train-mlogloss:0.379518	test-mlogloss:0.538741
# [300]	train-mlogloss:0.378963	test-mlogloss:0.538756
# [301]	train-mlogloss:0.378694	test-mlogloss:0.53891
# [302]	train-mlogloss:0.378352	test-mlogloss:0.538828
# [303]	train-mlogloss:0.377773	test-mlogloss:0.538813
# [304]	train-mlogloss:0.37736	test-mlogloss:0.538589
# [305]	train-mlogloss:0.376854	test-mlogloss:0.538657
# [306]	train-mlogloss:0.376321	test-mlogloss:0.538686
# [307]	train-mlogloss:0.375845	test-mlogloss:0.538628
# [308]	train-mlogloss:0.375528	test-mlogloss:0.538651
# [309]	train-mlogloss:0.375252	test-mlogloss:0.538597
# [310]	train-mlogloss:0.374822	test-mlogloss:0.538578
# [311]	train-mlogloss:0.374444	test-mlogloss:0.538524
# [312]	train-mlogloss:0.373904	test-mlogloss:0.538423
# [313]	train-mlogloss:0.37344	test-mlogloss:0.53836
# [314]	train-mlogloss:0.373116	test-mlogloss:0.538387
# [315]	train-mlogloss:0.372837	test-mlogloss:0.538376
# [316]	train-mlogloss:0.372567	test-mlogloss:0.538406
# [317]	train-mlogloss:0.372014	test-mlogloss:0.538283
# [318]	train-mlogloss:0.371655	test-mlogloss:0.538198
# [319]	train-mlogloss:0.371166	test-mlogloss:0.538234
# [320]	train-mlogloss:0.370695	test-mlogloss:0.538205
# [321]	train-mlogloss:0.370268	test-mlogloss:0.538214
# [322]	train-mlogloss:0.369692	test-mlogloss:0.538158
# [323]	train-mlogloss:0.369225	test-mlogloss:0.538259
# [324]	train-mlogloss:0.368768	test-mlogloss:0.538401
# [325]	train-mlogloss:0.368265	test-mlogloss:0.538413
# [326]	train-mlogloss:0.367783	test-mlogloss:0.53837
# [327]	train-mlogloss:0.367337	test-mlogloss:0.538302
# [328]	train-mlogloss:0.366858	test-mlogloss:0.538276
# [329]	train-mlogloss:0.366414	test-mlogloss:0.538331
# [330]	train-mlogloss:0.365931	test-mlogloss:0.538319
# [331]	train-mlogloss:0.365453	test-mlogloss:0.538184
# [332]	train-mlogloss:0.364929	test-mlogloss:0.538163
# [333]	train-mlogloss:0.364557	test-mlogloss:0.538194
# [334]	train-mlogloss:0.364101	test-mlogloss:0.538311
# [335]	train-mlogloss:0.363676	test-mlogloss:0.538166
# [336]	train-mlogloss:0.363139	test-mlogloss:0.538177
# [337]	train-mlogloss:0.362644	test-mlogloss:0.538109
# [338]	train-mlogloss:0.362181	test-mlogloss:0.538001
# [339]	train-mlogloss:0.361761	test-mlogloss:0.538067
# [340]	train-mlogloss:0.361448	test-mlogloss:0.538048
# [341]	train-mlogloss:0.360994	test-mlogloss:0.53819
# [342]	train-mlogloss:0.360627	test-mlogloss:0.538122
# [343]	train-mlogloss:0.360213	test-mlogloss:0.538109
# [344]	train-mlogloss:0.35972	test-mlogloss:0.537913
# [345]	train-mlogloss:0.359292	test-mlogloss:0.537782
# [346]	train-mlogloss:0.358942	test-mlogloss:0.537766
# [347]	train-mlogloss:0.358463	test-mlogloss:0.537756
# [348]	train-mlogloss:0.358084	test-mlogloss:0.537698
# [349]	train-mlogloss:0.357622	test-mlogloss:0.537681
# [350]	train-mlogloss:0.357322	test-mlogloss:0.537696
# [351]	train-mlogloss:0.356825	test-mlogloss:0.53773
# [352]	train-mlogloss:0.3565	test-mlogloss:0.53771
# [353]	train-mlogloss:0.356076	test-mlogloss:0.537698
# [354]	train-mlogloss:0.355565	test-mlogloss:0.537703
# [355]	train-mlogloss:0.355083	test-mlogloss:0.537703
# [356]	train-mlogloss:0.354724	test-mlogloss:0.537757
# [357]	train-mlogloss:0.354224	test-mlogloss:0.537774
# [358]	train-mlogloss:0.353927	test-mlogloss:0.537822
# [359]	train-mlogloss:0.353476	test-mlogloss:0.537815
# [360]	train-mlogloss:0.353114	test-mlogloss:0.537849
# [361]	train-mlogloss:0.352823	test-mlogloss:0.537778
# [362]	train-mlogloss:0.35244	test-mlogloss:0.537711
# [363]	train-mlogloss:0.352042	test-mlogloss:0.537729
# [364]	train-mlogloss:0.351607	test-mlogloss:0.537703
# [365]	train-mlogloss:0.35128	test-mlogloss:0.537719
# [366]	train-mlogloss:0.350908	test-mlogloss:0.537762
# [367]	train-mlogloss:0.350447	test-mlogloss:0.537748
# [368]	train-mlogloss:0.350026	test-mlogloss:0.537773
# [369]	train-mlogloss:0.349705	test-mlogloss:0.537754
# Stopping. Best iteration:
# [349]	train-mlogloss:0.357622	test-mlogloss:0.537681
#
# [0.53775380266503803]

# %%
preds, model = runXGB(train_X, train_y, test_X, num_rounds=1000)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_starter2.csv", index=False)

# %%
test_df
